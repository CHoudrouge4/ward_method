# %%
from sklearn.datasets.samples_generator import make_blobs
from random import *
import pandas as pd
import numpy as np

centers = []
for i in range(5):
    x = randint(-10, 10)
    y = randint(-10, 10)
    z = randint(-10, 10)
    centers.append([x, y, z])

#centers = [[2, 2], [8, 9], [9, 5], [3,9],[4,4],[0,0],[2,5]]
X, y = make_blobs(n_samples=5000, n_features=3, centers=centers, cluster_std=0.8, center_box=(1, 10.0), shuffle=True, random_state=0)

print(X[:, 0])
print(y)
# Out:
# [-0.92729148  8.34823312 -8.25243343 ... -2.25359577 -0.77059351
#  -8.39218448]
# [4 1 3 ... 0 2 3]

# %%
import matplotlib.pyplot as plt

#set colors for the clusters
colors = ['r','g','b','c','k','y','m']
c = []
for i in y:
    c.append(colors[i])

# %%
plt.scatter(X[:, 0], X[:, 1], X[:, 2], c= c)
plt.gray()
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot
import numpy as np

fig = pyplot.figure()
ax = Axes3D(fig)

ax.scatter(X[:, 0], X[:, 1], X[:, 2], c = c)
pyplot.show()

# %%
def read_file(file_name):
    array = []
    with open(result_25_16_5, 'r') as f:
        content = f.readline()
        print(content)
        for i in range(4):
            content = f.readline()
            content = content.split(' ')
            print(content[1])
            array.append(content[1])

result_25_16_5 = './results/result25_16_5.txt'
result_400_16_128 = './results/result400_16_128.txt'

# %%
data = {
   'Iris':   ['Item0', 'Item0', 'Item1'],
   'Cancer': ['Gold', 'Bronze', 'Gold'],
   'Digits': [1, 2, np.nan],
   'Boston': [1, 2, 2] }   
index= ['Ward', 'App-Ward (e = 0.5, VL = 5)', 'App-Ward (e = 4, VL = 5)']

df = pd.DataFrame(data, index)
    
df.head()
# Out:
#                              Iris  Cancer  Digits  Boston
# Ward                        Item0    Gold     1.0       1
# App-Ward (e = 0.5, VL = 5)  Item0  Bronze     2.0       2
# App-Ward (e = 4, VL = 5)    Item1    Gold     NaN       2
